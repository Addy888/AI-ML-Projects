# %% [markdown]
# <a href="https://colab.research.google.com/github/Addy888/AI-ML-Projects/blob/main/Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Salary%20Data.csv')

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14.plot(kind='scatter', x='Experience Years', y='Salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
df.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
y=df['Salary']
x=df[['Experience Years']]

# %%
from sklearn.model_selection import train_test_split

# %%
pd.read_csv("https://github.com/YBIFoundation/Dataset/raw/main/Salary%20Data.csv")
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2529)

# %%
x.shape,x_train.shape,x_test.shape
# Out:
# ((40, 1), (28, 1), (12, 1))

# %%
import seaborn as sns
sns.regplot(x='Experience Years',y='Salary',data=df)
# Out:
# <Axes: xlabel='Experience Years', ylabel='Salary'>

# %%
sklearn.linear_model.LinearRegression()
model = LinearRegression()

# %%
import sklearn.linear_model # Import the sklearn module
from sklearn.linear_model import LinearRegression # Import the LinearRegression class

sklearn.linear_model.LinearRegression() # Now you can use sklearn
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 26596.961311068262

# %%
model.coef_
# Out:
# array([9405.61663234])

# %%
model.predict(x_test)
# Out:
# array([ 90555.15441095,  59516.61952424, 106544.70268592,  64219.42784041,
#         68922.23615658, 123474.81262412,  84911.78443155,  63278.86617718,
#         65159.98950364,  61397.74285071,  37883.70126987,  50111.00289191])

# %%
y_test
# Out:
# 29     91738
# 11     60000
# 33    111620
# 16     56957
# 19     61111
# 38    122391
# 27     91000
# 14     63218
# 17     57081
# 12     57189
# 1      42774
# 6      48266
# Name: Salary, dtype: int64

# %%
x_test
# Out:
#     Experience Years
# 29               6.8
# 11               3.5
# 33               8.5
# 16               4.0
# 19               4.5
# 38              10.3
# 27               6.2
# 14               3.9
# 17               4.1
# 12               3.7
# 1                1.2
# 6                2.5
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_test['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_test['Experience Years'].plot(kind='line', figsize=(8, 4), title='Experience Years')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
y_pred = model.predict(x_test)

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.06384602996141632
